# %%
#task_1
#a
import pandas as pd
movie_performance = pd.read_csv('C:\\Users\\Katia\\Documents\\dc_marvel_movie_performance.csv')
movie_performance.head()
# Out:
#               Film U.S. release date  \
# 0         Superman        15/12/1978
# 1      Superman II        19/06/1981
# 2     Superman III        17/06/1983
# 3        Supergirl        21/11/1984
# 4  Howard the Duck        08/01/1986
#
#   Box office gross Domestic (U.S. and Canada )  \
# 0                                $134,478,449
# 1                                $108,185,706
# 2                                 $59,950,623
# 3                                 $14,296,438
# 4                                 $16,295,774
#
#   Box office gross Other territories Box office gross Worldwide        Budget  \
# 0                      $166,000,000               $300,478,449   $55,000,000
# 1                      $108,200,000               $216,385,706   $54,000,000
# 2                       $20,300,000                $80,250,623   $39,000,000
# 3                                NaN               $14,296,438   $35,000,000
# ...

# %%
movie_performance.tail()
# Out:
#                              Film U.S. release date  \
# 108                     The Flash        16/06/2023
# 109                   Blue Beetle        18/08/2023
# 110                   The Marvels        11/10/2023
# 111  Aquaman and the Lost Kingdom        20/12/2023
# 112                    Madame Web        14/02/2024
#
#     Box office gross Domestic (U.S. and Canada )  \
# 108                                $108,133,313
# 109                                 $72,488,072
# 110                                 $84,500,223
# 111                                $124,436,589
# 112                                 $42,619,699
#
#     Box office gross Other territories Box office gross Worldwide  \
# 108                      $162,500,000               $270,633,313
# 109                       $56,800,000               $129,288,072
# 110                      $121,373,601               $205,873,824
# 111                      $309,900,000               $434,336,589
# ...

# %%
print(movie_performance.columns)
# Out:
# Index(['Film', 'U.S. release date',
#        'Box office gross Domestic (U.S. and Canada )',
#        'Box office gross Other territories', 'Box office gross Worldwide',
#        'Budget', 'MCU', 'Phase', 'Distributor', 'MPAA Rating', 'Length',
#        'Minutes', 'Franchise', 'Character Family', 'Domestic %',
#        'Gross to Budget', 'Rotten Tomatoes Critic Score', 'Male/Female-led',
#        'Year', 'Inflation Adjusted Worldwide Gross',
#        'Inflation Adjusted Budget', '2.5x prod', 'Break Even'],
#       dtype='object')

# %%
#b
columns_to_remove = ['MCU', 'Phase', 'Franchise']
movie_performance = movie_performance.drop(columns=columns_to_remove)

# %%
print(movie_performance.columns)
# Out:
# Index(['Film', 'U.S. release date',
#        'Box office gross Domestic (U.S. and Canada )',
#        'Box office gross Other territories', 'Box office gross Worldwide',
#        'Budget', 'Distributor', 'MPAA Rating', 'Length', 'Minutes',
#        'Character Family', 'Domestic %', 'Gross to Budget',
#        'Rotten Tomatoes Critic Score', 'Male/Female-led', 'Year',
#        'Inflation Adjusted Worldwide Gross', 'Inflation Adjusted Budget',
#        '2.5x prod', 'Break Even'],
#       dtype='object')

# %%
#c
character_family=movie_performance.drop_duplicates(subset=['Character Family'], keep='first', inplace = False)

# %%
character_family.head()
# Out:
#                         Film U.S. release date  \
# 0                   Superman        15/12/1978
# 4            Howard the Duck        08/01/1986
# 6  The Return of Swamp Thing        05/12/1989
# 7                     Batman        23/06/1989
# 8               The Punisher        10/05/1989
#
#   Box office gross Domestic (U.S. and Canada )  \
# 0                                $134,478,449
# 4                                 $16,295,774
# 6                                    $192,816
# 7                                $251,409,241
# 8                                          $0
#
#   Box office gross Other territories Box office gross Worldwide        Budget  \
# 0                      $166,000,000               $300,478,449   $55,000,000
# 4                       $21,667,000                $37,962,774   $37,000,000
# 6                           $82,112                   $274,928    $3,000,000
# 7                      $160,160,000               $411,569,241   $35,000,000
# ...

# %%
character_family = character_family['Character Family'].sort_values()
print(character_family)
# Out:
# 59                            Ant-Man
# 81                            Aquaman
# 47                           Avengers
# 7                              Batman
# 88                      Birds of Prey
# 74                      Black Panther
# 91                        Black Widow
# 14                              Blade
# 109                       Blue Beetle
# 45                    Captain America
# 82                     Captain Marvel
# 26                        Constantine
# 18                          Daredevil
# 66                     Doctor Strange
# 95                           Eternals
# 28                     Fantastic Four
# 108                             Flash
# 31                        Ghost Rider
# 44                      Green Lantern
# 57            Guardians of the Galaxy
# 4                     Howard the Duck
# 20                               Hulk
# 34                           Iron Man
# 41                          Jonah Hex
# 62                     Justice League
# ...

# %%
#d 
longest_row_index = movie_performance['Length'].idxmax()
longest_row = movie_performance.loc[longest_row_index]

print(longest_row)
# Out:
# Film                                                              Avengers: Endgame
# U.S. release date                                                        26/04/2019
# Box office gross Domestic (U.S. and Canada )                          $858,373,000
# Box office gross Other territories                                  $1,941,066,100
# Box office gross Worldwide                                          $2,799,439,100
# Budget                                                                $356,000,000
# Distributor                                     Walt Disney Studios Motion Pictures
# MPAA Rating                                                                   PG-13
# Length                                                                     03:01:00
# Minutes                                                                         181
# Character Family                                                           Avengers
# ...

# %%
#e
mean_per_break_even = movie_performance.groupby('Break Even')['Rotten Tomatoes Critic Score'].mean()
print(mean_per_break_even)
# Out:
# Break Even
# Flop       42.361702
# Success    76.727273
# Name: Rotten Tomatoes Critic Score, dtype: float64

# %%
#f
movie_performance['Recomended'] = movie_performance['Rotten Tomatoes Critic Score'].apply(lambda x: 'Strongly Yes' if x >= 90 else ('Yes' if (x >= 60 and x < 90) else ('No' if (x >= 40 and x < 60) else 'Strongly No')))
movie_performance.head()
# Out:
#               Film U.S. release date  \
# 0         Superman        15/12/1978
# 1      Superman II        19/06/1981
# 2     Superman III        17/06/1983
# 3        Supergirl        21/11/1984
# 4  Howard the Duck        08/01/1986
#
#   Box office gross Domestic (U.S. and Canada )  \
# 0                                $134,478,449
# 1                                $108,185,706
# 2                                 $59,950,623
# 3                                 $14,296,438
# 4                                 $16,295,774
#
#   Box office gross Other territories Box office gross Worldwide        Budget  \
# 0                      $166,000,000               $300,478,449   $55,000,000
# 1                      $108,200,000               $216,385,706   $54,000,000
# 2                       $20,300,000                $80,250,623   $39,000,000
# 3                                NaN               $14,296,438   $35,000,000
# ...

# %%
movie_performance.value_counts("Recomended")
# Out:
# Recomended
# Yes             44
# Strongly No     30
# Strongly Yes    24
# No              15
# Name: count, dtype: int64

# %%
movie_performance.value_counts("Recomended", normalize = True)
# Out:
# Recomended
# Yes             0.389381
# Strongly No     0.265487
# Strongly Yes    0.212389
# No              0.132743
# Name: proportion, dtype: float64

# %%
#g
character_family_agg = movie_performance.pivot_table(index='Character Family', columns='Break Even', aggfunc='size', fill_value=0).reset_index()
character_family_agg['Success Rate'] = character_family_agg['Success']/ (character_family_agg['Flop'] + character_family_agg['Success'])
character_family_agg['Success Rate'] = character_family_agg['Success Rate'].apply(lambda x: f"{x:.2%}")
print(character_family_agg)
# Out:
# Break Even                Character Family  Flop  Success Success Rate
# 0                                  Ant-Man     1        2       66.67%
# 1                                  Aquaman     1        1       50.00%
# 2                                 Avengers     0        4      100.00%
# 3                                   Batman     3        9       75.00%
# 4                            Birds of Prey     1        0        0.00%
# 5                            Black Panther     0        2      100.00%
# 6                              Black Widow     1        0        0.00%
# 7                                    Blade     1        2       66.67%
# 8                              Blue Beetle     1        0        0.00%
# 9                          Captain America     0        3      100.00%
# 10                          Captain Marvel     1        1       50.00%
# 11                             Constantine     1        0        0.00%
# ...

# %%
#h
import pandas as pd
directors = pd.read_csv('C:\\Users\\Katia\\Documents\\directors.csv')
directors.head()
# Out:
#           Movie         Director
# 0  Man of Steel      Zack Snyder
# 1         Steel  Kenneth Johnson
# 2      Superman   Richard Donner
# 3  Superman III   Richard Lester
# 4   Superman II   Richard Lester

# %%
#i
merged_df=pd.merge(movie_performance, directors, how='inner', left_on='Film', right_on='Movie')

# %%
merged_df.head()
# Out:
#                                Film U.S. release date  \
# 0                          Superman        15/12/1978
# 1                       Superman II        19/06/1981
# 2                      Superman III        17/06/1983
# 3                         Supergirl        21/11/1984
# 4  Superman IV: The Quest for Peace        24/07/1987
#
#   Box office gross Domestic (U.S. and Canada )  \
# 0                                $134,478,449
# 1                                $108,185,706
# 2                                 $59,950,623
# 3                                 $14,296,438
# 4                                 $15,681,020
#
#   Box office gross Other territories Box office gross Worldwide        Budget  \
# 0                      $166,000,000               $300,478,449   $55,000,000
# 1                      $108,200,000               $216,385,706   $54,000,000
# 2                       $20,300,000                $80,250,623   $39,000,000
# ...

# %%
columns_to_remove = ['Movie']
merged_df = merged_df.drop(columns=columns_to_remove)

# %%
merged_df.head()
# Out:
#                                Film U.S. release date  \
# 0                          Superman        15/12/1978
# 1                       Superman II        19/06/1981
# 2                      Superman III        17/06/1983
# 3                         Supergirl        21/11/1984
# 4  Superman IV: The Quest for Peace        24/07/1987
#
#   Box office gross Domestic (U.S. and Canada )  \
# 0                                $134,478,449
# 1                                $108,185,706
# 2                                 $59,950,623
# 3                                 $14,296,438
# 4                                 $15,681,020
#
#   Box office gross Other territories Box office gross Worldwide        Budget  \
# 0                      $166,000,000               $300,478,449   $55,000,000
# 1                      $108,200,000               $216,385,706   $54,000,000
# 2                       $20,300,000                $80,250,623   $39,000,000
# ...

# %%
#task_2
#a
top_5_earnings = movie_performance['Gross to Budget'].nlargest(5)
top_5_earnings_rows = movie_performance[movie_performance['Gross to Budget'].isin(top_5_earnings)]
top_5_earnings_rows.head()
# Out:
#                        Film U.S. release date  \
# 7                    Batman        23/06/1989
# 61                 Deadpool        02/12/2016
# 79                    Venom        10/05/2018
# 87                    Joker        10/04/2019
# 96  Spider-Man: No Way Home        17/12/2021
#
#    Box office gross Domestic (U.S. and Canada )  \
# 7                                 $251,409,241
# 61                                $363,070,709
# 79                                $213,515,506
# 87                                $335,477,657
# 96                                $814,115,070
#
#    Box office gross Other territories Box office gross Worldwide  \
# 7                       $160,160,000               $411,569,241
# 61                      $419,541,446               $782,612,155
# 79                      $642,569,645               $856,085,151
# 87                      $743,480,625             $1,078,958,282
# 96                    $1,107,732,041             $1,921,847,111
#
# ...

# %%
films = top_5_earnings_rows['Film'].tolist()
print(films)
# Out:
# ['Batman', 'Deadpool', 'Venom', 'Joker', 'Spider-Man: No Way Home']

# %%
gross_to_budget = top_5_earnings_rows['Gross to Budget'].tolist()
print(gross_to_budget)
# Out:
# [11.76, 13.49, 8.56, 19.62, 9.61]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.bar(films, gross_to_budget)
ax.set_ylabel('earnings')
ax.set_title('films earnings')
plt.xticks(rotation=45)
plt.show()

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.8 kB ? eta -:--:--
#      ---------------- -------------------- 71.7/162.8 kB 975.2 kB/s eta 0:00:01
#      -------------------------------------- 162.8/162.8 kB 1.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#    - -------------------------------------- 0.2/7.7 MB 4.1 MB/s eta 0:00:02
#    - -------------------------------------- 0.4/7.7 MB 5.7 MB/s eta 0:00:02
#    --- ------------------------------------ 0.7/7.7 MB 5.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.9/7.7 MB 5.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/7.7 MB 5.1 MB/s eta 0:00:02
#    ------- -------------------------------- 1.4/7.7 MB 5.4 MB/s eta 0:00:02
#    -------- ------------------------------- 1.7/7.7 MB 5.4 MB/s eta 0:00:02
# ...

# %%
#b
recomened_counts = movie_performance.value_counts("Recomended")
values = recomened_counts.index.tolist()
counts = recomened_counts.values.tolist()
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.pie(counts, labels=values, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x222d6da3c50>,
# ...
#  [Text(0.37462513457445645, 1.034241755367221, 'Yes'),
#   Text(-1.0893892405338461, -0.15241746162789263, 'Strongly No'),
#   Text(0.07639317840216293, -1.0973441038678868, 'Strongly Yes'),
#   Text(1.0057275340788296, -0.4455469977406614, 'No')],
#  [Text(0.20434098249515803, 0.5641318665639387, '38.9%'),
#   Text(-0.5942123130184614, -0.0831367972515778, '26.5%'),
#   Text(0.04166900640117978, -0.5985513293824837, '21.2%'),
#   Text(0.5485786549520888, -0.24302563513126985, '13.3%')])
